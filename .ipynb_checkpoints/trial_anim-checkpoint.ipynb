# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# Fixing random state for reproducibility
np.random.seed(19680801)


def gen_rand_line(length, dims=2):
    """
    Create a line using a random walk algorithm.

    Parameters
    ----------
    length : int
        The number of points of the line.
    dims : int
        The number of dimensions of the line.
    """
    line_data = np.empty((dims, length))
    line_data[:, 0] = np.random.rand(dims)
    for index in range(1, length):
        # scaling the random numbers by 0.1 so
        # movement is small compared to position.
        # subtraction by 0.5 is to change the range to [-0.5, 0.5]
        # to allow a line to move backwards.
        step = (np.random.rand(dims) - 0.5) * 0.1
        line_data[:, index] = line_data[:, index - 1] + step
    return line_data


def update_lines(num, data_lines, lines):
    for line, data in zip(lines, data_lines):
        # NOTE: there is no .set_data() for 3 dim data...
        line.set_data(data[0:2, :num])
        line.set_3d_properties(data[2, :num])
    return lines


# Attaching 3D axis to the figure
fig = plt.figure()
ax = fig.add_subplot(projection="3d")

# Fifty lines of random 3-D lines
data = [gen_rand_line(25, 3) for index in range(50)]

# Creating fifty line objects.
# NOTE: Can't pass empty arrays into 3d version of plot()
lines = [ax.plot(dat[0, 0:1], dat[1, 0:1], dat[2, 0:1])[0] for dat in data]

# Setting the axes properties
ax.set_xlim3d([0.0, 1.0])
ax.set_xlabel('X')

ax.set_ylim3d([0.0, 1.0])
ax.set_ylabel('Y')

ax.set_zlim3d([0.0, 1.0])
ax.set_zlabel('Z')

ax.set_title('3D Test')

# Creating the Animation object
line_ani = animation.FuncAnimation(
    fig, update_lines, 50, fargs=(data, lines), interval=50)

plt.show()

# %%
# Out:
# MovieWriter stderr:
# dyld: Library not loaded: @rpath/libopenh264.5.dylib
#   Referenced from: /Users/sashwathnalinkanth/opt/anaconda3/lib/libavcodec.58.54.100.dylib
#   Reason: image not found
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     250         try:
# --> 251             yield self
#     252         finally:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1144                         frame_number += 1
# -> 1145                 writer.grab_frame(**savefig_kwargs)
#    1146
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in grab_frame(self, **savefig_kwargs)
#     362         # Save the figure data to the sink, using the frame format and dpi.
# --> 363         self.fig.savefig(self._frame_sink(), format=self.frame_format,
#     364                          dpi=self.dpi, **savefig_kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in print_raw(self, filename_or_obj, *args)
#     455         with cbook.open_file_cm(filename_or_obj, "wb") as fh:
# --> 456             fh.write(renderer.buffer_rgba())
#     457
#
# BrokenPipeError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in _repr_html_(self)
#    1377         fmt = mpl.rcParams['animation.html']
#    1378         if fmt == 'html5':
# -> 1379             return self.to_html5_video()
#    1380         elif fmt == 'jshtml':
#    1381             return self.to_jshtml()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1318                                 bitrate=mpl.rcParams['animation.bitrate'],
#    1319                                 fps=1000. / self._interval)
# -> 1320                 self.save(str(path), writer=writer)
#    1321                 # Now open and base64 encode.
#    1322                 vid64 = base64.encodebytes(path.read_bytes())
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1143                         progress_callback(frame_number, total_frames)
#    1144                         frame_number += 1
# -> 1145                 writer.grab_frame(**savefig_kwargs)
#    1146
#    1147     def _step(self, *args):
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     129                 value = type()
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#     133                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     251             yield self
#     252         finally:
# --> 253             self.finish()
#     254
#     255
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in finish(self)
#     352     def finish(self):
#     353         """Finish any processing for writing the movie."""
# --> 354         self.cleanup()
#     355
#     356     def grab_frame(self, **savefig_kwargs):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in cleanup(self)
#     388                 "MovieWriter stderr:\n%s", err)
#     389         if self._proc.returncode:
# --> 390             raise subprocess.CalledProcessError(
#     391                 self._proc.returncode, self._proc.args, out, err)
#     392
#
# CalledProcessError: Command '['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '432x288', '-pix_fmt', 'rgba', '-r', '20.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', '/var/folders/jk/rs1tnnr94dl8pqbvss08dng40000gn/T/tmpsaeh8dv8/temp.m4v']' died with <Signals.SIGABRT: 6>.

# %%
# Out:
# MovieWriter stderr:
# dyld: Library not loaded: @rpath/libopenh264.5.dylib
#   Referenced from: /Users/sashwathnalinkanth/opt/anaconda3/lib/libavcodec.58.54.100.dylib
#   Reason: image not found
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     250         try:
# --> 251             yield self
#     252         finally:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1144                         frame_number += 1
# -> 1145                 writer.grab_frame(**savefig_kwargs)
#    1146
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in grab_frame(self, **savefig_kwargs)
#     362         # Save the figure data to the sink, using the frame format and dpi.
# --> 363         self.fig.savefig(self._frame_sink(), format=self.frame_format,
#     364                          dpi=self.dpi, **savefig_kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in print_raw(self, filename_or_obj, *args)
#     455         with cbook.open_file_cm(filename_or_obj, "wb") as fh:
# --> 456             fh.write(renderer.buffer_rgba())
#     457
#
# BrokenPipeError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in _repr_html_(self)
#    1377         fmt = mpl.rcParams['animation.html']
#    1378         if fmt == 'html5':
# -> 1379             return self.to_html5_video()
#    1380         elif fmt == 'jshtml':
#    1381             return self.to_jshtml()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1318                                 bitrate=mpl.rcParams['animation.bitrate'],
#    1319                                 fps=1000. / self._interval)
# -> 1320                 self.save(str(path), writer=writer)
#    1321                 # Now open and base64 encode.
#    1322                 vid64 = base64.encodebytes(path.read_bytes())
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1143                         progress_callback(frame_number, total_frames)
#    1144                         frame_number += 1
# -> 1145                 writer.grab_frame(**savefig_kwargs)
#    1146
#    1147     def _step(self, *args):
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     129                 value = type()
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#     133                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     251             yield self
#     252         finally:
# --> 253             self.finish()
#     254
#     255
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in finish(self)
#     352     def finish(self):
#     353         """Finish any processing for writing the movie."""
# --> 354         self.cleanup()
#     355
#     356     def grab_frame(self, **savefig_kwargs):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in cleanup(self)
#     388                 "MovieWriter stderr:\n%s", err)
#     389         if self._proc.returncode:
# --> 390             raise subprocess.CalledProcessError(
#     391                 self._proc.returncode, self._proc.args, out, err)
#     392
#
# CalledProcessError: Command '['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '432x288', '-pix_fmt', 'rgba', '-r', '20.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', '/var/folders/jk/rs1tnnr94dl8pqbvss08dng40000gn/T/tmpxb5itfei/temp.m4v']' died with <Signals.SIGABRT: 6>.
